# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('../Downloads/000_data.csv')

# %%
df.head()
# Out:
#    rec_id obc_timeStamp obc_sensor gps_validity gps_utcTime   gps_latitude  \
# 0    4811    00:11:45.9        ALL           ok    00.11.43  38°09.601877N
# 1    4812    00:11:46.1        ALL           ok    00.11.44  38°09.602835N
# 2    4813    00:11:46.2        ALL           ok    00.11.44  38°09.602835N
# 3    4814    00:11:46.3        ALL           ok    00.11.44  38°09.602835N
# 4    4815    00:11:46.4        ALL           ok    00.11.44  38°09.602835N
#
#     gps_longitude  gps_fixQuality  gps_dilution  gps_speed  ...  \
# 0  122°27.188569W             1.0           1.2        2.1  ...
# 1  122°27.188991W             1.0           1.2        6.0  ...
# 2  122°27.188991W             1.0           1.2        6.0  ...
# 3  122°27.188991W             1.0           1.2        6.0  ...
# 4  122°27.188991W             1.0           1.2        6.0  ...
#
#    e_Road_Load_Total  e_Road_Load_netJoules  e_Road_Load_Total_Force  \
# ...

# %%
df.describe()
# Out:
#              rec_id  gps_fixQuality  gps_dilution     gps_speed   jm_netJoule  \
# count  14346.000000         14346.0  14346.000000  14346.000000  14346.000000
# mean   11983.500000             1.0      1.143322     24.090813   1770.677332
# std     4141.477816             0.0      0.173144     10.167290    336.345766
# min     4811.000000             1.0      0.800000      0.000000   1132.000000
# 25%     8397.250000             1.0      1.100000     15.500000   1477.000000
# 50%    11983.500000             1.0      1.200000     25.100000   1754.000000
# 75%    15569.750000             1.0      1.300000     33.300000   2102.750000
# max    19156.000000             1.0      1.400000     42.000000   2598.000000
#
#          jm_voltage    jm_current  lfm_temperature  lfm_integratedCorrFlow  \
# count  14346.000000  14346.000000     14346.000000            14346.000000
# mean   12824.550816     74.570403        28.007765               17.597182
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14346 entries, 0 to 14345
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   rec_id                       14346 non-null  int64
#  1   obc_timeStamp                14346 non-null  object
#  2   obc_sensor                   14346 non-null  object
#  3   gps_validity                 14346 non-null  object
#  4   gps_utcTime                  14346 non-null  object
#  5   gps_latitude                 14346 non-null  object
#  6   gps_longitude                14346 non-null  object
#  7   gps_fixQuality               14346 non-null  float64
#  8   gps_dilution                 14346 non-null  float64
#  9   gps_speed                    14346 non-null  float64
#  10  jm_netJoule                  14346 non-null  float64
#  11  jm_voltage                   14346 non-null  float64
# ...

# %%
gps_speed = np.array(df['gps_speed'])
time = list(df['Time'])

# %%
from itertools import count
import random
from matplotlib.animation import FuncAnimation
# %matplotlib notebook

# %%
#time = [i[3:] for i in time]
time
# Out:
# [0.1960833333333333,
#  0.1961388888888888,
#  0.1961666666666666,
#  0.1961944444444444,
#  0.1962222222222222,
#  0.1962499999999999,
#  0.1962777777777777,
#  0.1963055555555555,
#  0.1963333333333333,
#  0.1963611111111111,
#  0.1963888888888888,
#  0.1964166666666666,
#  0.1964444444444444,
#  0.1964722222222222,
#  0.1964999999999999,
#  0.1965277777777777,
#  0.1965555555555555,
#  0.1965833333333333,
#  0.1966111111111111,
#  0.1966388888888888,
#  0.1966666666666666,
#  0.1966944444444444,
#  0.1967222222222222,
#  0.1967499999999999,
#  0.1967777777777777,
#  0.1968055555555555,
#  0.1968333333333333,
#  0.1968611111111111,
#  0.1968888888888888,
#  0.1969166666666666,
#  0.1969444444444444,
#  0.1969722222222222,
#  0.1969999999999999,
#  0.1970277777777777,
#  0.1970555555555555,
#  0.1970833333333333,
#  0.1971111111111111,
#  0.1971666666666666,
#  0.1971944444444444,
#  0.1972222222222222,
#  0.1972499999999999,
#  0.1972777777777777,
#  0.1973055555555555,
# ...

# %%
gps_speed[0:10]
# Out:
# array([2.1, 6. , 6. , 6. , 6. , 6. , 6. , 6. , 6. , 6. ])

# %%
j = count()

# %%
next(j)
# Out:
# 2

# %%
sns.set_style('darkgrid')
plt.xlabel('Time')
plt.ylabel('Velocity')
plt.title('UC Gasoline Speed')
plt.plot(time[:50], gps_speed[:50], 'b')
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
time[:0]
# Out:
# []

# %%
x_vals = []
y_vals = []
i = 1
# %matplotlib notebook
sns.set_style('darkgrid')

def animate(i):
    #x_vals = append(time[:i])
    #y_vals = append(gps_speed[:i])
    x = time[:1000]
    y = gps_speed[:1000]
    plt.cla()
    plt.xlabel('Time')
    plt.ylabel('Velocity')
    plt.title('UC Gasoline Speed')
    plt.plot(x, y, 'b')
    
animation = FuncAnimation(fig = plt.gcf(), func = animate, frames = 50, interval = 1000, repeat = False)
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
df.columns
# Out:
# Index(['rec_id', 'obc_timeStamp', 'obc_sensor', 'gps_validity', 'gps_utcTime',
#        'gps_latitude', 'gps_longitude', 'gps_fixQuality', 'gps_dilution',
#        'gps_speed', 'jm_netJoule', 'jm_voltage', 'jm_current',
#        'lfm_temperature', 'lfm_integratedCorrFlow', 'lfm_instantFlow',
#        'gfs_gasFlow', 'gfs_gasTemp', 'gfs_netGasVolume', 'Lap',
#        'GPS Delta Distance(m)', 'GPS Distance (m)', 'GPS Speed (m/s)',
#        'Acceleration (m/s^2)', 'Grade (m/m)', 'e_accel', 'e_grade',
#        'Roll Resistance coef', 'e_roll_resistance', 'e_drag',
#        'e_Road_Load_Total', 'e_Road_Load_netJoules', 'e_Road_Load_Total_Force',
#        'e_Road_Load_Work', 'LFM_vol_int', 'LFM_corr', 'LFM_corr_int',
#        'LFM Integrated Fuel Economy', 'Instant BSFC', 'Time'],
#       dtype='object')

# %%
df['jm_voltage'][:1000]
# Out:
# 0      13992.0
# 1      13946.0
# 2      13946.0
# 3      13946.0
# 4      13946.0
#         ...
# 995    12751.0
# 996    12751.0
# 997    12751.0
# 998    12751.0
# 999    12751.0
# Name: jm_voltage, Length: 1000, dtype: float64

# %%
plt.plot(time[:1000], df['jm_voltage'][:1000])
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.plot(gps_speed[:1000], df['jm_voltage'][:1000], )
# Out:
# <img src="data:image/png;base64,..." width="432">
